# %%
import tweepy
import pandas as pd

consumer_key="Yvazs6LMFpLwiUAtzR7DOSeth"
consumer_secret="J8wSvr6oKG2NzQH0ML6WhnC4l4O19O66BWLJpNNW69OWAfsl7d"

access_token="2939559158-4VcTbuEehOzH1okEi8bwYKAnguesyxH9nBZAAYX"
access_secret="nYTX0qekKiO4zT8Gf8nE7lAY8YzOKArSsIwPFmFq2ILmP"


auth=tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)

api=tweepy.API(auth)  

modi_tweets=api.user_timeline('narendramodi',page=1,count=200)
len(modi_tweets)



df_modi_tweets=pd.DataFrame()
for tweet in modi_tweets:
    curr_tweet={
        'text':tweet.text,
        'likes':tweet.favorite_count,
        'retweets':tweet.retweet_count,
        'created_at':tweet.created_at,
        "source":tweet.source
    }
    df_modi_tweets=df_modi_tweets.append(curr_tweet,ignore_index=True)
    
df_modi_tweets
# Out:
#              created_at    likes  retweets                source  \
# 0   2019-10-29 20:54:45   5475.0     947.0    Twitter for iPhone
# 1   2019-10-29 20:54:34   7422.0    1163.0    Twitter for iPhone
# 2   2019-10-29 20:52:32   4482.0     744.0    Twitter for iPhone
# 3   2019-10-29 19:01:53   7744.0    1367.0    Twitter for iPhone
# 4   2019-10-29 19:00:07   5351.0    1160.0    Twitter for iPhone
# 5   2019-10-29 18:58:38   3781.0     786.0    Twitter for iPhone
# 6   2019-10-29 18:56:02  13973.0    2631.0  Twitter Media Studio
# 7   2019-10-29 18:55:24   4552.0     979.0  Twitter Media Studio
# 8   2019-10-29 18:54:52   4190.0     920.0  Twitter Media Studio
# 9   2019-10-29 18:54:27   4460.0     956.0  Twitter Media Studio
# 10  2019-10-29 16:40:36   9380.0    1600.0    Twitter for iPhone
# 11  2019-10-29 16:35:13  11318.0    2049.0    Twitter for iPhone
# 12  2019-10-29 16:25:37   6413.0    1157.0    Twitter for iPhone
# 13  2019-10-29 16:22:32   5071.0     861.0    Twitter for iPhone
# 14  2019-10-29 15:07:59  11728.0    2723.0             Periscope
# 15  2019-10-29 14:05:42  11124.0    1755.0    Twitter for iPhone
# 16  2019-10-29 14:04:45  10358.0    1425.0    Twitter for iPhone
# 17  2019-10-29 13:43:43   7759.0    1377.0    Twitter for iPhone
# 18  2019-10-29 13:41:55   5256.0     908.0    Twitter for iPhone
# 19  2019-10-29 13:15:08  13082.0    1851.0    Twitter for iPhone
# 20  2019-10-29 13:14:02   9371.0    1259.0    Twitter for iPhone
# 21  2019-10-29 07:31:30  21067.0    3427.0    Twitter for iPhone
# 22  2019-10-29 05:59:32  48588.0    5845.0    Twitter for iPhone
# 23  2019-10-28 20:36:23  27924.0    3711.0    Twitter for iPhone
# 24  2019-10-28 20:35:00  49445.0    9500.0    Twitter for iPhone
# 25  2019-10-28 14:27:21   8068.0    1477.0    Twitter for iPhone
# 26  2019-10-28 14:24:49  23687.0    3773.0    Twitter for iPhone
# 27  2019-10-28 14:22:01  38279.0    4575.0    Twitter for iPhone
# 11   التقيت بصاحب الجلالة KingSalman@. إنه أحد أكثر...
# 12   Interacted with HE Ahmad Bin Salman Al Rajhi, ...
# 13   عقدت لقاء مع سعادة وزير القوى العاملة \nوالتنم...
# 14   Speaking at @FIIKSA in Riyadh. Watch. https://...
# 15   Adding even more energy to the India-Saudi Ara...
# 16   سوف تساهم الزيارة في دعم أواصر  الصداقة \nبين ...
# 17   Wonderful meeting with HE @AlfadleyA, Minister...
# 18   عقدت لقاء رائع مع سعادة وزير البيئة و المياه \...
# 19   Excellent meeting with His Majesty @KingAbdull...
# 20   لقاء ممتاز مع صاحب الجلالة KingAbdullahII@ في ...
# 21   Sharing my interview with @arabnews, where I s...
# 22   भाई-बहन के स्नेह और प्यार के प्रतीक पर्व भाई द...
# 23   Landed in the Kingdom of Saudi Arabia, marking...
# 24   وصلت إلى المملكة العربية السعودية في مستهل زيا...
# 25   Yesterday’s #MannKiBaat covered topics such as...
# 26   PM @BorisJohnson wonderfully explains the esse...
# 27   My dear friend Bibi, thank you for the Diwali ...
# 28   As always, @POTUS @realDonaldTrump marks Diwal...
# 29   Thoughtful greetings by PM @JustinTrudeau. \n\...
# ..                                                 ...
# 170  हमारा सपना - सूखामुक्त भारत, सूखामुक्त जालना। ...
# 171  मराठवाड़ा से कांग्रेस के कई मुख्यमंत्री हुए, ल...
# 172  Congress finally admits- it needs lessons in n...
# 173  Top INC-NCP leaders are going to be defeated! ...
# 174  People in Jalna are happy with the work of the...
# 175  Come to Akola to see the wide support for BJP!...
# 176  ଓଡିଶାର ମୁଖ୍ୟମନ୍ତ୍ରୀ ଶ୍ରୀ ନବୀନ ପଟ୍ଟନାୟକଜୀଙ୍କୁ  ...
# 177  स्वरोजगार को बढ़ावा देने के लिए सरकार हर प्रया...
# 178  राष्ट्रहित में, हरियाणा के हित में जो भी उचित ...
# 179  जब-जब, जिस-जिस बात को लेकर देश खुश होता है, उस...
# 180  Through the power of their vote, the people of...
# 181  Haryana's Nari Shakti is excelling in all fiel...
# 182  Campaigned in Dadri and Kurukshetra. \n\nThese...
# 183  Speaking in Kurukshetra. Watch my speech. http...
# 184  The mood in Haryana favours BJP’s development ...
# 185  This month’s #MannKiBaat will take place on 27...
# 186  An important milestone in the journey of creat...
# 187  Birthday wishes to @DrMNPandeyMP Ji. He is wor...
# 188  Greetings to @naqvimukhtar Ji on his birthday....
# 189  डॉ. एपीजे अब्दुल कलाम जी को उनकी जयंती पर विनम...
# 190  Earlier today, had a very good meeting with Ki...
# 191  हरियाणा में सरकारी भर्ती का मतलब पहले होता था-...
# 192  देश की राय साफ है। अब सिर्फ विरोध और प्रतिरोध ...
# 193  आर्टिकल 370 के कारण दलितों के साथ अन्याय हो रह...
# 194  कुछ लोग आर्टिकल 370 के फैसले पर सवाल उठा रहे ह...
# 195  Five years ago, the Congress mocked us and ask...
# 196  I also congratulate Esther Duflo and Michael K...
# 197  Congratulations to Abhijit Banerjee on being c...
# 198  Haryana supports BJP’s development agenda. Wat...
# 199  विपक्ष को चुनौती है कि यदि हिम्मत है तो स्पष्ट...
#
# [200 rows x 5 columns]

# %%
df_modi_tweets.to_csv('modi_tweets.csv')

# %%
import numpy as np
import pandas as pd
import string
import nltk
#nltk.download('stopwords')
from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('modi_tweets.csv')
df.head()
# Out:
#    Unnamed: 0           created_at   likes  retweets              source  \
# 0           0  2019-10-29 20:54:45  5475.0     947.0  Twitter for iPhone
# 1           1  2019-10-29 20:54:34  7422.0    1163.0  Twitter for iPhone
# 2           2  2019-10-29 20:52:32  4482.0     744.0  Twitter for iPhone
# 3           3  2019-10-29 19:01:53  7744.0    1367.0  Twitter for iPhone
# 4           4  2019-10-29 19:00:07  5351.0    1160.0  Twitter for iPhone
#
#                                                 text
# 0  I would like to particularly thank His Majesty...
# 1  I am extremely grateful to the people and Gove...
# 2  أشعر بامتنان كبير للسعودية شعبا وحكومة \r\nلكر...
# 3  It is always a delight to meet His Royal Highn...
# 4  أسعد دوما بلقاء صاحب السمو الملكي الأمير محمد ...

# %%
text['Clean_text'] = text['text'].str.lower().str.replace('[^a-z ]', '')

# Removing the stop words

stop = set(stopwords.words('english'))

# If you want to extend the stopword list

# stop.extend(['use', 'im'])

def sw(text):
    text = [word for word in text.split() if word not in stop]
    # joining the list of words with space separator
    return " ".join(text)

text['Split_words'] = text['Clean_text'].apply(sw)

text.head()

# create a count vectorizer object
count_vectorizer = CountVectorizer()
# fit the count vectorizer using the text data
count_vectorizer.fit(text["Split_words"])
# collect the vocabulary items used in the vectorizer
dictionary = count_vectorizer.vocabulary_.items()

# Creating DTM
X = count_vectorizer.fit_transform(text['Split_words'])

# Converting a DTM to a DTM data frame
DTM = pd.DataFrame(X.toarray(), columns=count_vectorizer.get_feature_names())
DTM.head()

# Word and they freq

word_count_freq = DTM.sum()

#word_count_freq.sort_values(ascending=False)

Word_table = pd.DataFrame(word_count_freq).reset_index()

Word_table = Word_table.rename(columns={"index" : 'Word', 0 : "Freq"})

Word_table.sort_values(by = 'Freq', ascending = False).head()
# Out:
# C:\Users\DELL\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\DELL\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#        Word  Freq
# 999   watch    15
# 752  people    14
# 184  diwali    13
# 536   india    10
# 973      us    10

# %%
# top 10 words used by customers in review

Top_10_words = Word_table.sort_values(by = 'Freq', ascending = False).head(10)

Top_10_words

# Plotting the top 10 words

plt.rcParams['figure.figsize'] = [15, 5]
plt.bar(Top_10_words['Word'], Top_10_words['Freq'], width=0.5)
plt.xlabel("Words")
plt.ylabel("Word Frequency")
plt.title("Top 10 words")

plt.show()

# %%
# Creating a word cloud

# Libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Step 1: Create the wordcloud object

input_string = ' '.join(text['Split_words'])

wordcloud = WordCloud(width=480, height=480, margin=0, background_color="skyblue").generate(input_string)

# Step 2: Display the generated image

plt.rcParams['figure.figsize'] = [10, 5]
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
